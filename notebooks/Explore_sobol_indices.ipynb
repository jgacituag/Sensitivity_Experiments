# %%
from sobol_tools import ProblemSpec, analyze_saltelli_exact, plot_sobol_bars, save_sobol_to_csv

names  = ["stability_factor","int_total_shear","total_shear_depth","curved_shear_per","mid_level_moisture_factor"]
bounds = [(-1.5,1.5),(0,30),(4000,8000),(0,1),(-10,10)]   # physical or [0,1] both OK
problem = ProblemSpec(names, bounds)
